# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.cluster import KMeans
import pandas as pd

# %%
data={
    "customer":['aman','riya','ahemed','ali','zara'],
    'age':[20,21,22,23,24],
    'spending':[10000,12000,30000,13000,25000]
}

# %%
df=pd.DataFrame(data)

# %%
df
# Out:
#   customer  age  spending
# 0     aman   20     10000
# 1     riya   21     12000
# 2   ahemed   22     30000
# 3      ali   23     13000
# 4     zara   24     25000

# %%
x=df[['age','spending']]

# %%
model=KMeans(n_clusters=2,random_state=42,n_init=10)

# %%
df['Group']=model.fit_predict(x)
plt.figure(figsize=(6,5))
for i in df['Group'].unique():
    group_data=df[df['Group']==i]
    plt.scatter(group_data['age'],group_data['spending'])
# Out:
# c:\Users\GT-Tech\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:1419: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=1.
#   warnings.warn(

# %%
df
# Out:
#   customer  age  spending  Group
# 0     aman   20     10000      0
# 1     riya   21     12000      0
# 2   ahemed   22     30000      1
# 3      ali   23     13000      0
# 4     zara   24     25000      1

# %% [markdown]
# PRINCIPAL COMPOSTION ANAYLISIS (PCA)

# %%
from sklearn.preprocessing import StandardScaler
from sklearn.decomposition import PCA
import numpy as np
import matplotlib.pyplot as plt

import pandas as pd
data2={
    'age':[20,21,22,23,24],
    'income':[10000,12000,30000,13000,25000],
    'spending':[30,40,50,40,70],
    'saving':[1000,1500,3000,1200,2000]
}
df=pd.DataFrame(data2)
scale=StandardScaler()
scaled_data=scale.fit_transform(df)
pca=PCA(n_components=2)
pca_result=pca.fit_transform(scaled_data)
pca_df=pd.DataFrame(pca_result,columns=['pca1','pca2'])
explained_varience=pca.explained_variance_ratio_
print(np.round(explained_varience *100 ,2))
plt.scatter(pca_df['pca1'],pca_df['pca2'])
plt.show()
print(pca_df)
# Out:
# [75.42 21.07]
#        pca1      pca2
# 0 -2.291687 -0.366818
# 1 -1.117634 -0.156535
# 2  1.819017 -1.450826
# 3 -0.620751  0.968118
# 4  2.211055  1.006060

# %%
scaled_data
# Out:
# array([[-1.41421356, -1.00313973, -1.17953565, -1.03580115],
#        [-0.70710678, -0.75235479, -0.44232587, -0.33593551],
#        [ 0.        ,  1.50470959,  0.29488391,  1.76366141],
#        [ 0.70710678, -0.62696233, -0.44232587, -0.75585489],
#        [ 1.41421356,  0.87774726,  1.76930347,  0.36393013]])

# %%
pca
# Out:
# PCA(n_components=2)

# %%
pca_result
# Out:
# array([[-2.29168665, -0.3668185 ],
#        [-1.11763429, -0.1565348 ],
#        [ 1.81901686, -1.45082562],
#        [-0.62075057,  0.96811847],
#        [ 2.21105465,  1.00606045]])

# %%
pca_df
# Out:
#        pca1      pca2
# 0 -2.291687 -0.366818
# 1 -1.117634 -0.156535
# 2  1.819017 -1.450826
# 3 -0.620751  0.968118
# 4  2.211055  1.006060

# %%
print(np.round(explained_varience *100 ,2))
# Out:
# [75.42 21.07]

# %%
explained_varience
# Out:
# array([0.75419252, 0.21066825])
